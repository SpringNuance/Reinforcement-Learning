# %% [markdown]
# <div class="alert alert-block alert-info">
#    <h2 align="center"> <center><b> Reinforcement Learning Assignment 1 - The Reinforcement Learning Framework</b></center></h2>
#
# <br>
# <center><font size="3">This notebook is a part of teaching material for ELEC-E8125</font></center>
# <center><font size="3">Sep 4, 2023 - Nov 30, 2023</font></center>
# <center><font size="3">Aalto University</font></center>
# </div>
#
#
# <a id='TOC'></a>
#
# <div class="alert alert-block alert-success">
#
# # Table of contents
# * <a href='#1.'> 1. Introduction </a>
# * <a href='#1.1'> 1.1 Learning Objectives </a>
# * <a href='#1.2'> 1.2 Code Structure & Files </a>
# * <a href='#2.'> 2. Cartpole</a>
# * <a href='#3.'> 3. Reacher</a>
# * <a href='#4.'> 4. Submitting </a>
# * <a href='#4.1'> 4.1 Feedback </a>
# * <a href='#5.'> References</a>
#
# <a href='#T1'><b>Student Task 1.</b> Training a Model for Simple Cartpole Environment (10 points)</a>\
# <a href='#Q1'><b>Student Question 1.1</b> Learning (10 points)</a>\
# <a href='#T2'><b>Student Task 2.</b> Investigating Training Performance (10 points) </a>\
# <a href='#Q2'><b>Student Question 2.1</b> Analysis of Training Performance (15 points) </a>\
# <a href='#Q3'><b>Student Question 2.2</b> Stochasticity (10 points) </a>\
# <a href='#T3'><b>Student Task 3.</b> Reward Functions (20 points) </a>\
# <a href='#T4'><b>Student Task 4.</b> Visualizing Behavior (10 points) </a>\
# <a href='#Q4'><b>Student Question 4.1</b> Achieved Peformance (5 points)\
# <a href='#Q5'><b>Student Question 4.2</b> Analysis of Behaviour (10 points)</a>
#
# **Total Points:** 100

# %% [markdown]
# # 1. Introduction <a id='1.'></a>
# In this exercise we will take a first look at a reinforcement learning environment, its components and modify the reward function of a simple agent.
#
# In this notebook two environments are used: Cartpole and Reacher. The cartpole environment is taken from [OpenAI's Gym library](https://www.gymlibrary.dev/). The reacher environment is custom made (and defined in ```reacher.py```) but utilizes the Gym API.
#
# ## 1.1 Learning Objectives: <a id='1.1'></a>
# - To become familiar with assignment structure and the agent-environment relationshp
# - To understand the effects of stochasticity
# - To understand and explore the effects of task definition
#
# ## 1.2 Code Structure & Files <a id='1.2'></a>
#
# The ```train.py``` file instantiates the environment and the RL agent that acts in it. The ```agent.py``` file contains the implementation of a simple reinforcement learning agent; for the sake of this exercise, you can assume it to be a black box (you don’t need to understand how it works, although you are encouraged to study it in more detail). You don’t have to edit any other file other than ```ex1.ipynb``` to complete this exercise.
# ```
# ├───cfg                  # Config files for environments e.g. define the maximum number of steps in an episode.
# ├───imgs                 # Images used in notebook
# ├───results
# │   ├───logging          # Contains logged data
# │   ├───model            # Contains the policies learned
# │   └───video            # Contains videos for each environment
# │       └───CartPole-v0
# │       │  └───test      # Videos saved during testing
# │       │  └───train     # Videos saved during training
# │       └───SpinningReacher-v0
# │           └───test
# │           └───train
# ├───wandb                # Data saved for wandb
# │   ex1.ipynb            # Main assignment file containing tasks <---------
# │   feedback.ipynb       # Please give feedback in here
# │   README.ipynb         # This file
# │   agent.py             # Contains functions that govern the policy
# │   reacher.py           # Defines the reacher environment
# │   train.py             # Contains training and testing functions
# │   utils.py             # Contains useful functions
# ```

# %% [markdown]
# Please consult ```README.md``` for more details the assignments.
#
# The assignments use wandb to visualize data. You need to set Wandb up and login using the command below.

# %%
! wandb login 34902633b7a1636949fce4d030bcc5c861e19bc5 # Insert API key here. You can get your API key from https://wandb.ai/authorize
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /home/nguyenb5/.netrc

# %%
from pathlib import Path # to find directory
work_dir = Path().cwd()/'results'
import os
os.environ['WANDB_NOTEBOOK_NAME'] = str(Path().cwd()/'ex1.ipynb') # Detects notebook for wandb

import train as t # for training
import utils as u # helper functions

import numpy as np # The numpy library can be used for math functions
import torch # Used to manage policy and learning
from IPython.display import Video, display, HTML # to display videos

# %% [markdown]
# # 2. Cartpole <a id='2.'></a>
#
# The Cartpole environment consists of a cart and a pole mounted on top of it, as shown in Figure 1. The cart can move either to the left or to the right. The goal is to balance the pole in a vertical position in order to prevent it from falling down. The cart should also stay within limited distance from the center (trying to move outside screen boundaries is considered a failure).
#
# <figure>
# <img src="imgs/cartpole.png" width="400px">
# <figcaption style="text-align: center"> Figure 1: The Cartpole environment  </figcaption>
# </figure>
#
# The state and the observation are four element vectors:
#
# $$
# o=s=\left(\begin{array}{c}
# x \\
# \dot{x} \\
# \theta \\
# \dot{\theta}
# \end{array}\right) \text {, }
# $$
#
# where $x$ is the position of the cart, $\dot{x}$ is its velocity, $\theta$ is the angle of the pole w.r.t. the vertical axis, and $\dot{\theta}$ is the angular velocity of the pole.
#
# In the standard formulation, a reward of 1 is given for every timestep the pole remains balanced. Upon failing (the pole falls) or completing the task, an episode is finished.
#
# The training script will record videos of the agent’s learning progress during training, and the recorded videos are saved to ```results/video/CartPole-v0/train```. By default, the training information is saved to ```results/logging/CartPole-v0_logging.pkl``` as well as on cloud via wandb. When the training is finished, the models are saved to ```results/model/Cartpole-v0_params.pt```. The models can be tested by setting ```testing=true``` in ```cfg_args```, and if the models are saved to a different path, you can use ```model_path=<YOUR MODEL PATH>``` to indicate it. Videos of the agent’s behaviour during testing are saved to ```results/video/CartPole-v0/test```.

# %% [markdown]
# <a id='T1'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 1.</b> Training a Model for Simple Cartpole Environment (10 points) </h3>
#
# This task requires you to train a model for the cartpole environment with 100 timesteps per episode and then report the training plot using 'Weights \& Biases'. Then test the model for 1000 timesteps and report average reward. To do this, you can simply run the code in the cells below.
#
# To see a full list of options that can be passed through ```cfg_args``` consult the configuation file found in ```cfg/```.
#
# - **1st:** setup 'Weights \& Biases', check the README for help.
# - **2nd:** Run training over 100 steps per episode by using ```t.train``` function. See the cell below.
# - **3rd:** Export the training plot ```episodesep_reward``` from wandb (see ```README.md```) and attach below.
# - **4th:** Run testing over 1000 steps by using ```t.test``` function. See the cell below. See the cell below. Notice ```max_episode_steps``` parameter.
# - **5th:** Report the average reward after testing the model.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
t.train(cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
        cfg_args=dict(seed=1, max_episode_steps=100, silent=True)) # < 5 mins
# Out:
# Numpy/Torch/Random Seed:  1
# Finishing last run (ID:ki1yw0sj) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>ep_reward</td><td>▃▁▁▂▁▂▄▂▃▁▁▂▁▂▂▃▁█▂▂▁▂▂▁▄▁▃▂▂▁▅▆▃▆▃▂▆▂▅▁</td></tr><tr><td>episodes</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>num_updates</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>timesteps</td><td>▃▁▁▂▁▂▄▂▃▁▁▂▁▂▂▃▁█▂▂▁▂▂▁▄▁▃▂▂▁▅▆▃▆▃▂▆▂▅▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>ep_reward</td><td>10.0</td></tr><tr><td>episodes</td><td>155</td></tr><tr><td>num_updates</td><td>0</td></tr><tr><td>timesteps</td><td>10</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ex1-CartPole-v1-1-1694691005</strong> at: <a href='https://wandb.ai/springnuance/rl_aalto/runs/ki1yw0sj' target="_blank">https://wandb.ai/springnuance/rl_aalto/runs/ki1yw0sj</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230914_143005-ki1yw0sj/logs</code>
# Successfully finished last run (ID:ki1yw0sj). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016670028089235227, max=1.0…
# wandb version 0.15.10 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/notebooks/rl2023/ex1/wandb/run-20230914_143117-cqgmt3rr</code>
# Syncing run <strong><a href='https://wandb.ai/springnuance/rl_aalto/runs/cqgmt3rr' target="_blank">ex1-CartPole-v1-1-1694691077</a></strong> to <a href='https://wandb.ai/springnuance/rl_aalto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/springnuance/rl_aalto' target="_blank">https://wandb.ai/springnuance/rl_aalto</a>
#  View run at <a href='https://wandb.ai/springnuance/rl_aalto/runs/cqgmt3rr' target="_blank">https://wandb.ai/springnuance/rl_aalto/runs/cqgmt3rr</a>
# Configuration Settings: {'exp_name': 'ex1', 'seed': 1, 'env_name': 'CartPole-v1', 'max_episode_steps': 100, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': True, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Model saved to /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt
# ------Training finished.------

# %% [markdown]
# The training figure of the CartPole environment is:
#
# <figure>
# <img src="imgs/Task1.png" width="800px">
# <figcaption style="text-align: center"> Figure 2: The episode rewards plot for the trained model  </figcaption>
# </figure>

# %% [markdown]
# The command below will evaluate the trained model in 10 episodes and report the average reward (and episode length) for these 10 episodes.

# %%
t.test(episodes=10, 
       cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
       cfg_args=dict(testing=True, seed=None, max_episode_steps=1000, use_wandb=False))
# Out:
# Numpy/Torch/Random Seed:  501
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 137.0 seed: 88
# Test ep reward: 127.0 seed: 672
# Test ep reward: 131.0 seed: 680
# Test ep reward: 127.0 seed: 592
# Test ep reward: 135.0 seed: 481
# Test ep reward: 137.0 seed: 78
# Test ep reward: 147.0 seed: 735
# Test ep reward: 156.0 seed: 852
# Test ep reward: 132.0 seed: 694
# Test ep reward: 126.0 seed: 965
# Average test reward: 135.5 episode length: 135.5

# %% [markdown]
# The average reward after testing the model is 135.5

# %% [markdown]
# The agent acting in the environment can be seen using the following command. Change the ```path``` to pick the episode you want to visualize. Bear in mind by default video saving for training is taken every 50 episodes.

# %%
# Train Result
video_dir = work_dir/'video'/'CartPole-v1'/'train'

# List all MP4 files in the directory
mp4_files = [file for file in os.listdir(video_dir) if file.endswith(".mp4")]
frame_colors = ['#FF5733', '#33FF57', '#5733FF', '#FFFF33', '#33FFFF', '#FF33FF']
# Display each MP4 file
for i, mp4_file in enumerate(mp4_files):
    video_path = os.path.join(video_dir, mp4_file)
    video = Video(video_path, embed=True, html_attributes="loop autoplay", width=200, height=100)
    frame_color = frame_colors[i % len(frame_colors)]
    video_frame = HTML(f'<div style="width: 200px; height: 100px;; border: 1px solid #FF5733;">{video._repr_html_()}</div>')
    print("test/",mp4_file)
    display(video_frame)
# Out:
# test/ ex1-episode-0.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-50.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-100.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-150.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-200.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-250.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-300.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-350.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-400.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-450.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-500.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>

# %%
# Test Result

video_dir = work_dir/'video'/'CartPole-v1'/'test'

# List all MP4 files in the directory
mp4_files = [file for file in os.listdir(video_dir) if file.endswith(".mp4")]
frame_colors = ['#FF5733', '#33FF57', '#5733FF', '#FFFF33', '#33FFFF', '#FF33FF']
# Display each MP4 file
for i, mp4_file in enumerate(mp4_files):
    video_path = os.path.join(video_dir, mp4_file)
    video = Video(video_path, embed=True, html_attributes="loop autoplay", width=200, height=100)
    frame_color = frame_colors[i % len(frame_colors)]
    video_frame = HTML(f'<div style="width: 200px; height: 100px;; border: 1px solid #5733FF;">{video._repr_html_()}</div>')
    print("test/",mp4_file)
    display(video_frame)
# Out:
# test/ ex1-episode-0.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-1.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-2.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-3.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-4.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-5.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-6.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-7.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-8.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-9.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_100-episode-1.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_100-episode-0.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_200-episode-0.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_300-episode-0.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_400-episode-0.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_500-episode-0.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_100-episode-2.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_100-episode-3.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_100-episode-4.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_100-episode-5.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_100-episode-6.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_100-episode-7.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_100-episode-8.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_100-episode-9.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_200-episode-1.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_200-episode-2.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_200-episode-3.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_200-episode-4.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_200-episode-5.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_200-episode-6.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_200-episode-7.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_200-episode-8.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_200-episode-9.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_300-episode-1.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_300-episode-2.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_300-episode-3.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_300-episode-4.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_300-episode-5.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_300-episode-6.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_300-episode-7.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_300-episode-8.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_300-episode-9.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_400-episode-1.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_400-episode-2.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_400-episode-3.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_400-episode-4.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_400-episode-5.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_400-episode-6.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_400-episode-7.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_400-episode-8.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_400-episode-9.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_500-episode-1.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_500-episode-2.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_500-episode-3.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_500-episode-4.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_500-episode-5.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_500-episode-6.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_500-episode-7.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_500-episode-8.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1_seed_500-episode-9.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>

# %% [markdown]
# <a id='Q1'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 1.1</b> Learning (10 points) </h3>
#
# Test the trained model from Task 1 five times with different random seeds. Did the same model, trained to balance for 100 timesteps, learn to always balance the pole for 1000 timesteps? Why/why not?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
t.test(episodes=10, 
       cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
       cfg_args=dict(testing=True, exp_name="ex1_seed_100", seed=100, max_episode_steps=1000, silent=True, use_wandb=False))

t.test(episodes=10, 
       cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
       cfg_args=dict(testing=True, exp_name="ex1_seed_200", seed=200, max_episode_steps=1000, silent=True, use_wandb=False))

t.test(episodes=10, 
       cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
       cfg_args=dict(testing=True, exp_name="ex1_seed_300", seed=300, max_episode_steps=1000, silent=True, use_wandb=False))

t.test(episodes=10, 
       cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
       cfg_args=dict(testing=True, exp_name="ex1_seed_400", seed=400, max_episode_steps=1000, silent=True, use_wandb=False))

t.test(episodes=10, 
       cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
       cfg_args=dict(testing=True, exp_name="ex1_seed_500", seed=500, max_episode_steps=1000, silent=True, use_wandb=False))
# Out:
# Numpy/Torch/Random Seed:  100
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 129.0 seed: 100
# Test ep reward: 129.0 seed: 100
# Test ep reward: 129.0 seed: 100
# Test ep reward: 129.0 seed: 100
# Test ep reward: 129.0 seed: 100
# Test ep reward: 129.0 seed: 100
# Test ep reward: 129.0 seed: 100
# Test ep reward: 129.0 seed: 100
# Test ep reward: 129.0 seed: 100
# Test ep reward: 129.0 seed: 100
# Average test reward: 129.0 episode length: 129.0
# Numpy/Torch/Random Seed:  200
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 124.0 seed: 200
# Test ep reward: 124.0 seed: 200
# Test ep reward: 124.0 seed: 200
# Test ep reward: 124.0 seed: 200
# Test ep reward: 124.0 seed: 200
# Test ep reward: 124.0 seed: 200
# Test ep reward: 124.0 seed: 200
# Test ep reward: 124.0 seed: 200
# Test ep reward: 124.0 seed: 200
# Test ep reward: 124.0 seed: 200
# Average test reward: 124.0 episode length: 124.0
# Numpy/Torch/Random Seed:  300
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 133.0 seed: 300
# Test ep reward: 133.0 seed: 300
# Test ep reward: 133.0 seed: 300
# Test ep reward: 133.0 seed: 300
# Test ep reward: 133.0 seed: 300
# Test ep reward: 133.0 seed: 300
# Test ep reward: 133.0 seed: 300
# Test ep reward: 133.0 seed: 300
# Test ep reward: 133.0 seed: 300
# Test ep reward: 133.0 seed: 300
# Average test reward: 133.0 episode length: 133.0
# Numpy/Torch/Random Seed:  400
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 143.0 seed: 400
# Test ep reward: 143.0 seed: 400
# Test ep reward: 143.0 seed: 400
# Test ep reward: 143.0 seed: 400
# Test ep reward: 143.0 seed: 400
# Test ep reward: 143.0 seed: 400
# Test ep reward: 143.0 seed: 400
# Test ep reward: 143.0 seed: 400
# Test ep reward: 143.0 seed: 400
# Test ep reward: 143.0 seed: 400
# Average test reward: 143.0 episode length: 143.0
# Numpy/Torch/Random Seed:  500
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 141.0 seed: 500
# Test ep reward: 141.0 seed: 500
# Test ep reward: 141.0 seed: 500
# Test ep reward: 141.0 seed: 500
# Test ep reward: 141.0 seed: 500
# Test ep reward: 141.0 seed: 500
# Test ep reward: 141.0 seed: 500
# Test ep reward: 141.0 seed: 500
# Test ep reward: 141.0 seed: 500
# Test ep reward: 141.0 seed: 500
# Average test reward: 141.0 episode length: 141.0

# %% [markdown]
# I run the testing for seed values of 100, 200, 300, 400, 500 and the results are shown above
#
# Out of the 5 random seeds, the testing reward using falls in the range of 130-140. Therefore, my answer is that the pole is highly unlikely to be balanced for 1000 timesteps given any seed values. The reason for the failures is because the pole is only trained for 100 timesteps, which we cannot guarantee its balance in the step 10 times more than the training timesteps. The cause of failure is most often related to the cartpole moving outside of the screen.

# %% [markdown]
# <a id='T2'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 2.</b> Investigating Training Performance (10 points) </h3>
#
# Repeat the experiment in Task 1 five times, each time training the model from scratch with 100 timesteps and testing it for 1000 timesteps. Use a different seed number for each training/testing cycle. You can use the box below to write a small script to do this. Use the result textbox below to report the average test reward for each repeat.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
for seed_number in [100, 200, 300, 400, 500]:
    # Define the original and temporary file paths
    original_path = Path().cwd()/"results"/"model"/"CartPole-v1_params.pt"
    temp_path = Path().cwd()/"results"/"model"/"CartPole-v1_params_temp.pt"

    if original_path.exists():
        original_path.rename(temp_path)

    t.train(cfg_path=f"{Path().cwd()}/cfg/cartpole_v1.yaml",  
            cfg_args=dict(exp_name=f"ex1_task2_seed_{seed_number}", 
                          #model_path=f"CartPole-v1_Task2_seed_{seed_number}.yaml",
                          train_episodes=200, save_video=False, save_logging=False,
                          seed=seed_number, max_episode_steps=100,
                          silent=True, use_wandb=False)) 

    t.test(episodes=10, 
           cfg_path=f"{Path().cwd()}/cfg/cartpole_v1.yaml", 
           cfg_args=dict(testing=True, 
                         exp_name=f"ex1_task2_seed_{seed_number}", 
                         seed=seed_number, max_episode_steps=1000, 
                         save_video=False,
                         silent=True, use_wandb=False))

    new_path = Path().cwd()/"results"/"model"/f"CartPole-v1_params_ex1_task2_seed_{seed_number}.pt"

    if original_path.exists():
        original_path.rename(new_path)

    temp_path.rename(original_path)
# Out:
# Numpy/Torch/Random Seed:  100
# Configuration Settings: {'exp_name': 'ex1_task2_seed_100', 'seed': 100, 'env_name': 'CartPole-v1', 'max_episode_steps': 100, 'train_episodes': 200, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': False, 'save_model': True, 'save_logging': False, 'silent': True, 'use_wandb': False, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Model saved to /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt
# ------Training finished.------
# Numpy/Torch/Random Seed:  100
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 629.0 seed: 100
# Test ep reward: 629.0 seed: 100
# Test ep reward: 629.0 seed: 100
# Test ep reward: 629.0 seed: 100
# Test ep reward: 629.0 seed: 100
# Test ep reward: 629.0 seed: 100
# Test ep reward: 629.0 seed: 100
# Test ep reward: 629.0 seed: 100
# Test ep reward: 629.0 seed: 100
# Test ep reward: 629.0 seed: 100
# Average test reward: 629.0 episode length: 629.0
# Numpy/Torch/Random Seed:  200
# Configuration Settings: {'exp_name': 'ex1_task2_seed_200', 'seed': 200, 'env_name': 'CartPole-v1', 'max_episode_steps': 100, 'train_episodes': 200, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': False, 'save_model': True, 'save_logging': False, 'silent': True, 'use_wandb': False, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Model saved to /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt
# ------Training finished.------
# Numpy/Torch/Random Seed:  200
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 170.0 seed: 200
# Test ep reward: 170.0 seed: 200
# Test ep reward: 170.0 seed: 200
# Test ep reward: 170.0 seed: 200
# Test ep reward: 170.0 seed: 200
# Test ep reward: 170.0 seed: 200
# Test ep reward: 170.0 seed: 200
# Test ep reward: 170.0 seed: 200
# Test ep reward: 170.0 seed: 200
# Test ep reward: 170.0 seed: 200
# Average test reward: 170.0 episode length: 170.0
# Numpy/Torch/Random Seed:  300
# Configuration Settings: {'exp_name': 'ex1_task2_seed_300', 'seed': 300, 'env_name': 'CartPole-v1', 'max_episode_steps': 100, 'train_episodes': 200, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': False, 'save_model': True, 'save_logging': False, 'silent': True, 'use_wandb': False, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Model saved to /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt
# ------Training finished.------
# Numpy/Torch/Random Seed:  300
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 76.0 seed: 300
# Test ep reward: 76.0 seed: 300
# Test ep reward: 76.0 seed: 300
# Test ep reward: 76.0 seed: 300
# Test ep reward: 76.0 seed: 300
# Test ep reward: 76.0 seed: 300
# Test ep reward: 76.0 seed: 300
# Test ep reward: 76.0 seed: 300
# Test ep reward: 76.0 seed: 300
# Test ep reward: 76.0 seed: 300
# Average test reward: 76.0 episode length: 76.0
# Numpy/Torch/Random Seed:  400
# Configuration Settings: {'exp_name': 'ex1_task2_seed_400', 'seed': 400, 'env_name': 'CartPole-v1', 'max_episode_steps': 100, 'train_episodes': 200, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': False, 'save_model': True, 'save_logging': False, 'silent': True, 'use_wandb': False, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Model saved to /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt
# ------Training finished.------
# Numpy/Torch/Random Seed:  400
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 158.0 seed: 400
# Test ep reward: 158.0 seed: 400
# Test ep reward: 158.0 seed: 400
# Test ep reward: 158.0 seed: 400
# Test ep reward: 158.0 seed: 400
# Test ep reward: 158.0 seed: 400
# Test ep reward: 158.0 seed: 400
# Test ep reward: 158.0 seed: 400
# Test ep reward: 158.0 seed: 400
# Test ep reward: 158.0 seed: 400
# Average test reward: 158.0 episode length: 158.0
# Numpy/Torch/Random Seed:  500
# Configuration Settings: {'exp_name': 'ex1_task2_seed_500', 'seed': 500, 'env_name': 'CartPole-v1', 'max_episode_steps': 100, 'train_episodes': 200, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': False, 'save_model': True, 'save_logging': False, 'silent': True, 'use_wandb': False, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Updating the policy...
# Updating finished!
# Updating the policy...
# Updating finished!
# Model saved to /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt
# ------Training finished.------
# Numpy/Torch/Random Seed:  500
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 495.0 seed: 500
# Test ep reward: 495.0 seed: 500
# Test ep reward: 495.0 seed: 500
# Test ep reward: 495.0 seed: 500
# Test ep reward: 495.0 seed: 500
# Test ep reward: 495.0 seed: 500
# Test ep reward: 495.0 seed: 500
# Test ep reward: 495.0 seed: 500
# Test ep reward: 495.0 seed: 500
# Test ep reward: 495.0 seed: 500
# Average test reward: 495.0 episode length: 495.0

# %% [markdown]
# I run the training and testing for different seed values of 100, 200, 300, 400, 500 and these are the average test rewards (note: I only train for 200 episdoes instead of 500 episodes so it can differ from your model solution)
#
# Seed 100: Average test reward: 629.0
#
# Seed 200: Average test reward: 170.0
#
# Seed 300: Average test reward: 76.0
#
# Seed 400: Average test reward: 158.0
#
# Seed 500: Average test reward: 495.0

# %% [markdown]
# <a id='Q2'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 2.1</b> Analysis of Training Performance (15 points) </h3>
#
# Are the behavior and performance of the trained models the same every time? Why/why not? Analyze the causes briefly.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# As we can see from above, each time I run with a different seed number, the average test reward will change by standard deviation of 200. Therefore, the behavior and performance of the trained models will differ every time a different seed is used. This is because the training environment is stochastic by nature. The environment initial state is different each time and the transition action for each time step is also probabilistic for different seed number, which explains the underlying stochasticity of the model.

# %% [markdown]
# <a id='Q3'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 2.2</b> Stochasticity (10 points) </h3>
#
# What are the implications of this stochasticity, when it comes to comparing reinforcement learning algorithms to each other? Please explain.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# The stochasticity will first cause the variance in performance of the RL models, which we can see from above that each seed number results in a different average testing reward. Secondly, this randomness also causes the initial state to vary significantly, which many RL models are highly sensitive to. Additionally, the randomness may make the performance of RL models harder to quantify, as it is often unsure whether good performance is due to luck or due to the underlying algorithm. Therefore, when we compare RL algorithms, we should run multiple trials with different seed number and record the average performance plus its standard deviation (like Task 1). Additionally, we should use the same seed for comparing RL models to reproduce the same randomness and make them start from the same initial states so their performance is easier to compare than starting from different initial states.

# %% [markdown]
# # Reacher <a id='3.'></a>
#
# Now we will focus on designing a reward function for a different environment, the Reacher environment, where a two-joint manipulator needs to reach a goal (see Figure 2).
#
# <figure>
# <img src="imgs/reacher.png" width="200px">
# <figcaption style="text-align: center"> Figure 2: The Reacher environment  </figcaption>
# </figure>
#
# The Cartesian ($x$, $y$) position of the end-effector of the manipulator can be determined following the equation:
#
# $$
#  x = L_1 \sin(\theta_0)+L_2 \sin(\theta_0+\theta_1)\\
#  y = -L_1 \cos(\theta_0)-L_2 \cos(\theta_0+\theta_1)
# $$
#
# where $L1 = 1$, $L2 = 1$ are the lengths, and $\theta_0$, $\theta_1$ the joint angles of the first and second links respectively. The state (and observation) in this environment is the two element vector:
#
# $$
# o=s=\left(\begin{array}{c}
# \theta_0 \\
# \theta_1 \\
# \end{array}\right) \text {, }
# $$
#
# The action space now consists of 5 "options"; 4 correspond rotating the first/second joint left/right, and the final one performs no motion at all (the configuration doesn’t change). The episode terminates when the agent reaches the target position, marked in red. Now, let us design a custom reward function and use it for training the RL agent.

# %% [markdown]
# <a id='T3'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 3.</b> Reward Functions (20 points) </h3>
#
# Below two classes are shown that modify the reward function of the reacher function provided in ```reacher.py```. Edit the function ```get_reward``` _below_ (not in ```reacher.py```) in both classes. For each class, write a reward function to incentivise the agent to learn the following behaviors:
#
# Class 1) ```SpinningReacherEnv```: Keep the manipulator rotating clockwise continuously (w.r.t. angle θ_0). You can use a lower number of training episodes for this, e.g. train(cfg_args=dict(env_name='SpinningReacher-v0', train_episodes=200), overrides=['env=reacher_v1'])
#
# Class 2) ```TargetReacherEnv```: Reach the goal point located in x = [1.0,1.0] (marked in red). Use at least 500 training episodes.
#
# Train one model for each behavior.
#
# **Hint:** Use the observation vector to get the quantities required to compute the new reward (such as the position of the manipulator). You can get the Cartesian position of the end-effector with ```self.get_cartesian_pos(state)```.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
from reacher import ReacherEnv
from typing import Optional
from gymnasium.envs.registration import register

class SpinningReacherEnv(ReacherEnv):
    def __init__(self, render_mode: Optional[str] = None, max_episode_steps=200):
        super().__init__(render_mode=render_mode, max_episode_steps=max_episode_steps)

    def get_reward(self, prev_state, action, next_state):
        # TODO: Task 3: Implement and test the second reward function
        ########## Your code starts here ##########
        # Keep the manipulator rotating clockwise continuously (wrt angle θ0)
        if action == 1:
            return 1
        else:
            return 0
        ########## Your codes end here ########## 
        
register("SpinningReacher-v0",
        entry_point="%s:SpinningReacherEnv"%__name__,
        max_episode_steps=200)

class TargetReacherEnv(ReacherEnv):
    def __init__(self, render_mode: Optional[str] = None, max_episode_steps=200):
        super().__init__(render_mode=render_mode, max_episode_steps=max_episode_steps)

    def get_reward(self, prev_state, action, next_state):
        # TODO: Task 3: Implement and test the first reward function
        ########## Your code starts here ##########
        # Reach the goal point located in x = [1.0,1.0] (marked in red)
        next_position = self.get_cartesian_pos(next_state)
        euclidean_distance = np.sqrt(np.sum((next_position - self.goal)**2))
        # Since the algorithm tries to maximize while this distance needs to be minimized, 
        # a negative sign is needed for the distance
        return -euclidean_distance
        ########## Your codes end here ########## 
        


        
register("TargetReacher-v0",
        entry_point="%s:TargetReacherEnv"%__name__,
        max_episode_steps=200)
# Out:
# /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment SpinningReacher-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment TargetReacher-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
t.train(cfg_path=Path().cwd()/'cfg'/'reacher_v1.yaml', 
      cfg_args=dict(env_name='SpinningReacher-v0', train_episodes=200)) # < 5 mins
# Out:
# Numpy/Torch/Random Seed:  130
# Finishing last run (ID:c1ucn52f) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.007 MB of 0.007 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>ep_reward</td><td>▂▂▂▁▂▃▅▁▅▄▆▆▇▄▇▇▄▄▅▇▇▇▆█████████████████</td></tr><tr><td>episodes</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>num_updates</td><td>▁▁▁▁█▁▁▁▁▁▁▁▁▁▁█▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>timesteps</td><td>▇██▃█▅█▁█████▄██▄▄▅▇▇▇▅█████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>ep_reward</td><td>200</td></tr><tr><td>episodes</td><td>200</td></tr><tr><td>num_updates</td><td>0</td></tr><tr><td>timesteps</td><td>200</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ex1-SpinningReacher-v0-None-1694699565</strong> at: <a href='https://wandb.ai/springnuance/rl_aalto/runs/c1ucn52f' target="_blank">https://wandb.ai/springnuance/rl_aalto/runs/c1ucn52f</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230914_165246-c1ucn52f/logs</code>
# Successfully finished last run (ID:c1ucn52f). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016673643700778486, max=1.0…
# wandb version 0.15.10 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/notebooks/rl2023/ex1/wandb/run-20230914_165527-jiwzvfkq</code>
# Syncing run <strong><a href='https://wandb.ai/springnuance/rl_aalto/runs/jiwzvfkq' target="_blank">ex1-SpinningReacher-v0-None-1694699727</a></strong> to <a href='https://wandb.ai/springnuance/rl_aalto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/springnuance/rl_aalto' target="_blank">https://wandb.ai/springnuance/rl_aalto</a>
#  View run at <a href='https://wandb.ai/springnuance/rl_aalto/runs/jiwzvfkq' target="_blank">https://wandb.ai/springnuance/rl_aalto/runs/jiwzvfkq</a>
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2023/ex1/results/video/SpinningReacher-v0/train folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Configuration Settings: {'exp_name': 'ex1', 'seed': None, 'env_name': 'SpinningReacher-v0', 'max_episode_steps': 200, 'train_episodes': 200, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 2
# Action space dimensions: 5
#
# Episode 0 finished. Total reward: 43 (200 timesteps)
# Episode 1 finished. Total reward: 48 (200 timesteps)
# Episode 2 finished. Total reward: 42 (200 timesteps)
# Episode 3 finished. Total reward: 46 (200 timesteps)
# Episode 4 finished. Total reward: 43 (200 timesteps)
# Episode 5 finished. Total reward: 10 (87 timesteps)
# Episode 6 finished. Total reward: 46 (200 timesteps)
# Episode 7 finished. Total reward: 42 (200 timesteps)
# Episode 8 finished. Total reward: 43 (200 timesteps)
# Episode 9 finished. Total reward: 47 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 10 finished. Total reward: 52 (200 timesteps)
# Episode 11 finished. Total reward: 63 (200 timesteps)
# Episode 12 finished. Total reward: 52 (200 timesteps)
# Episode 13 finished. Total reward: 51 (200 timesteps)
# Episode 14 finished. Total reward: 50 (200 timesteps)
# Episode 15 finished. Total reward: 56 (200 timesteps)
# Episode 16 finished. Total reward: 42 (200 timesteps)
# Episode 17 finished. Total reward: 45 (200 timesteps)
# Episode 18 finished. Total reward: 35 (111 timesteps)
# Episode 19 finished. Total reward: 41 (134 timesteps)
# Episode 20 finished. Total reward: 44 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 21 finished. Total reward: 69 (200 timesteps)
# Episode 22 finished. Total reward: 69 (200 timesteps)
# Episode 23 finished. Total reward: 44 (119 timesteps)
# Episode 24 finished. Total reward: 18 (38 timesteps)
# Episode 25 finished. Total reward: 28 (78 timesteps)
# Episode 26 finished. Total reward: 35 (104 timesteps)
# Episode 27 finished. Total reward: 80 (200 timesteps)
# Episode 28 finished. Total reward: 56 (200 timesteps)
# Episode 29 finished. Total reward: 31 (99 timesteps)
# Episode 30 finished. Total reward: 96 (166 timesteps)
# Episode 31 finished. Total reward: 43 (139 timesteps)
# Episode 32 finished. Total reward: 41 (118 timesteps)
# Episode 33 finished. Total reward: 24 (61 timesteps)
# Episode 34 finished. Total reward: 74 (165 timesteps)
# Updating the policy...
# Updating finished!
# Episode 35 finished. Total reward: 103 (200 timesteps)
# Episode 36 finished. Total reward: 74 (200 timesteps)
# Episode 37 finished. Total reward: 53 (99 timesteps)
# Episode 38 finished. Total reward: 101 (200 timesteps)
# Episode 39 finished. Total reward: 90 (200 timesteps)
# Episode 40 finished. Total reward: 93 (200 timesteps)
# Episode 41 finished. Total reward: 55 (189 timesteps)
# Episode 42 finished. Total reward: 69 (200 timesteps)
# Episode 43 finished. Total reward: 17 (36 timesteps)
# Episode 44 finished. Total reward: 76 (200 timesteps)
# Episode 45 finished. Total reward: 23 (56 timesteps)
# Episode 46 finished. Total reward: 24 (63 timesteps)
# Episode 47 finished. Total reward: 97 (200 timesteps)
# Episode 48 finished. Total reward: 27 (77 timesteps)
# Updating the policy...
# Updating finished!
# Episode 49 finished. Total reward: 91 (200 timesteps)
# Episode 50 finished. Total reward: 102 (200 timesteps)
# Episode 51 finished. Total reward: 93 (200 timesteps)
# Episode 52 finished. Total reward: 57 (112 timesteps)
# Episode 53 finished. Total reward: 96 (200 timesteps)
# Episode 54 finished. Total reward: 32 (72 timesteps)
# Episode 55 finished. Total reward: 86 (200 timesteps)
# Episode 56 finished. Total reward: 105 (200 timesteps)
# Episode 57 finished. Total reward: 106 (200 timesteps)
# Episode 58 finished. Total reward: 107 (200 timesteps)
# Episode 59 finished. Total reward: 28 (60 timesteps)
# Episode 60 finished. Total reward: 20 (42 timesteps)
# Episode 61 finished. Total reward: 60 (116 timesteps)
# Updating the policy...
# Updating finished!
# Episode 62 finished. Total reward: 34 (80 timesteps)
# Episode 63 finished. Total reward: 103 (200 timesteps)
# Episode 64 finished. Total reward: 113 (200 timesteps)
# Episode 65 finished. Total reward: 115 (200 timesteps)
# Episode 66 finished. Total reward: 56 (99 timesteps)
# Episode 67 finished. Total reward: 61 (116 timesteps)
# Episode 68 finished. Total reward: 113 (200 timesteps)
# Episode 69 finished. Total reward: 119 (200 timesteps)
# Episode 70 finished. Total reward: 96 (166 timesteps)
# Episode 71 finished. Total reward: 120 (200 timesteps)
# Episode 72 finished. Total reward: 120 (200 timesteps)
# Episode 73 finished. Total reward: 101 (169 timesteps)
# Updating the policy...
# Updating finished!
# Episode 74 finished. Total reward: 23 (45 timesteps)
# Episode 75 finished. Total reward: 59 (99 timesteps)
# Episode 76 finished. Total reward: 127 (200 timesteps)
# Episode 77 finished. Total reward: 142 (200 timesteps)
# Episode 78 finished. Total reward: 63 (93 timesteps)
# Episode 79 finished. Total reward: 90 (127 timesteps)
# Episode 80 finished. Total reward: 124 (170 timesteps)
# Episode 81 finished. Total reward: 100 (161 timesteps)
# Episode 82 finished. Total reward: 131 (200 timesteps)
# Episode 83 finished. Total reward: 124 (200 timesteps)
# Episode 84 finished. Total reward: 91 (151 timesteps)
# Episode 85 finished. Total reward: 95 (140 timesteps)
# Episode 86 finished. Total reward: 55 (86 timesteps)
# Updating the policy...
# Updating finished!
# Episode 87 finished. Total reward: 136 (200 timesteps)
# Episode 88 finished. Total reward: 128 (179 timesteps)
# Episode 89 finished. Total reward: 151 (200 timesteps)
# Episode 90 finished. Total reward: 141 (200 timesteps)
# Episode 91 finished. Total reward: 89 (118 timesteps)
# Episode 92 finished. Total reward: 95 (132 timesteps)
# Episode 93 finished. Total reward: 122 (162 timesteps)
# Episode 94 finished. Total reward: 148 (200 timesteps)
# Episode 95 finished. Total reward: 117 (147 timesteps)
# Episode 96 finished. Total reward: 149 (200 timesteps)
# Episode 97 finished. Total reward: 142 (200 timesteps)
# Episode 98 finished. Total reward: 124 (159 timesteps)
# Updating the policy...
# Updating finished!
# Episode 99 finished. Total reward: 53 (70 timesteps)
# Episode 100 finished. Total reward: 161 (200 timesteps)
# Episode 101 finished. Total reward: 161 (200 timesteps)
# Episode 102 finished. Total reward: 150 (189 timesteps)
# Episode 103 finished. Total reward: 152 (187 timesteps)
# Episode 104 finished. Total reward: 117 (139 timesteps)
# Episode 105 finished. Total reward: 148 (200 timesteps)
# Episode 106 finished. Total reward: 164 (200 timesteps)
# Episode 107 finished. Total reward: 117 (139 timesteps)
# Episode 108 finished. Total reward: 155 (192 timesteps)
# Episode 109 finished. Total reward: 112 (134 timesteps)
# Episode 110 finished. Total reward: 84 (108 timesteps)
# Updating the policy...
# Updating finished!
# Episode 111 finished. Total reward: 175 (200 timesteps)
# Episode 112 finished. Total reward: 174 (200 timesteps)
# Episode 113 finished. Total reward: 168 (200 timesteps)
# Episode 114 finished. Total reward: 168 (200 timesteps)
# Episode 115 finished. Total reward: 165 (200 timesteps)
# Episode 116 finished. Total reward: 152 (172 timesteps)
# Episode 117 finished. Total reward: 83 (99 timesteps)
# Episode 118 finished. Total reward: 181 (200 timesteps)
# Episode 119 finished. Total reward: 176 (200 timesteps)
# Episode 120 finished. Total reward: 170 (200 timesteps)
# Episode 121 finished. Total reward: 151 (178 timesteps)
# Updating the policy...
# Updating finished!
# Episode 122 finished. Total reward: 176 (200 timesteps)
# Episode 123 finished. Total reward: 146 (166 timesteps)
# Episode 124 finished. Total reward: 141 (160 timesteps)
# Episode 125 finished. Total reward: 56 (71 timesteps)
# Episode 126 finished. Total reward: 174 (200 timesteps)
# Episode 127 finished. Total reward: 170 (200 timesteps)
# Episode 128 finished. Total reward: 151 (173 timesteps)
# Episode 129 finished. Total reward: 149 (174 timesteps)
# Episode 130 finished. Total reward: 185 (200 timesteps)
# Episode 131 finished. Total reward: 183 (200 timesteps)
# Episode 132 finished. Total reward: 179 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 133 finished. Total reward: 186 (200 timesteps)
# Episode 134 finished. Total reward: 185 (200 timesteps)
# Episode 135 finished. Total reward: 184 (200 timesteps)
# Episode 136 finished. Total reward: 173 (200 timesteps)
# Episode 137 finished. Total reward: 176 (200 timesteps)
# Episode 138 finished. Total reward: 186 (200 timesteps)
# Episode 139 finished. Total reward: 183 (194 timesteps)
# Episode 140 finished. Total reward: 193 (200 timesteps)
# Episode 141 finished. Total reward: 189 (200 timesteps)
# Episode 142 finished. Total reward: 176 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 143 finished. Total reward: 190 (200 timesteps)
# Episode 144 finished. Total reward: 189 (200 timesteps)
# Episode 145 finished. Total reward: 189 (200 timesteps)
# Episode 146 finished. Total reward: 181 (200 timesteps)
# Episode 147 finished. Total reward: 184 (200 timesteps)
# Episode 148 finished. Total reward: 192 (200 timesteps)
# Episode 149 finished. Total reward: 194 (200 timesteps)
# Episode 150 finished. Total reward: 189 (200 timesteps)
# Episode 151 finished. Total reward: 190 (200 timesteps)
# Episode 152 finished. Total reward: 177 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 153 finished. Total reward: 181 (200 timesteps)
# Episode 154 finished. Total reward: 184 (200 timesteps)
# Episode 155 finished. Total reward: 186 (200 timesteps)
# Episode 156 finished. Total reward: 188 (200 timesteps)
# Episode 157 finished. Total reward: 191 (200 timesteps)
# Episode 158 finished. Total reward: 190 (200 timesteps)
# Episode 159 finished. Total reward: 185 (200 timesteps)
# Episode 160 finished. Total reward: 188 (200 timesteps)
# Episode 161 finished. Total reward: 186 (200 timesteps)
# Episode 162 finished. Total reward: 187 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 163 finished. Total reward: 183 (200 timesteps)
# Episode 164 finished. Total reward: 189 (200 timesteps)
# Episode 165 finished. Total reward: 188 (200 timesteps)
# Episode 166 finished. Total reward: 191 (200 timesteps)
# Episode 167 finished. Total reward: 186 (200 timesteps)
# Episode 168 finished. Total reward: 187 (200 timesteps)
# Episode 169 finished. Total reward: 190 (200 timesteps)
# Episode 170 finished. Total reward: 191 (200 timesteps)
# Episode 171 finished. Total reward: 181 (200 timesteps)
# Episode 172 finished. Total reward: 184 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 173 finished. Total reward: 183 (200 timesteps)
# Episode 174 finished. Total reward: 187 (200 timesteps)
# Episode 175 finished. Total reward: 186 (200 timesteps)
# Episode 176 finished. Total reward: 182 (200 timesteps)
# Episode 177 finished. Total reward: 191 (200 timesteps)
# Episode 178 finished. Total reward: 186 (200 timesteps)
# Episode 179 finished. Total reward: 189 (200 timesteps)
# Episode 180 finished. Total reward: 191 (200 timesteps)
# Episode 181 finished. Total reward: 187 (200 timesteps)
# Episode 182 finished. Total reward: 186 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 183 finished. Total reward: 188 (200 timesteps)
# Episode 184 finished. Total reward: 190 (200 timesteps)
# Episode 185 finished. Total reward: 189 (200 timesteps)
# Episode 186 finished. Total reward: 188 (200 timesteps)
# Episode 187 finished. Total reward: 193 (200 timesteps)
# Episode 188 finished. Total reward: 195 (200 timesteps)
# Episode 189 finished. Total reward: 192 (200 timesteps)
# Episode 190 finished. Total reward: 190 (200 timesteps)
# Episode 191 finished. Total reward: 195 (200 timesteps)
# Episode 192 finished. Total reward: 190 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 193 finished. Total reward: 195 (200 timesteps)
# Episode 194 finished. Total reward: 196 (200 timesteps)
# Episode 195 finished. Total reward: 194 (200 timesteps)
# Episode 196 finished. Total reward: 194 (200 timesteps)
# Episode 197 finished. Total reward: 196 (200 timesteps)
# Episode 198 finished. Total reward: 196 (200 timesteps)
# Episode 199 finished. Total reward: 193 (200 timesteps)
# Episode 200 finished. Total reward: 197 (200 timesteps)
# Model saved to /notebooks/rl2023/ex1/results/model/SpinningReacher-v0_params.pt
# ------Training finished.------

# %%
t.test(episodes=10, cfg_path=Path().cwd()/'cfg'/'reacher_v1.yaml', 
       cfg_args=dict(env_name='SpinningReacher-v0', testing=True, use_wandb=False))
# Out:
# Numpy/Torch/Random Seed:  665
# Loading model from /notebooks/rl2023/ex1/results/model/SpinningReacher-v0_params.pt ...
# Testing...
# Test ep reward: 200 seed: 234
# Test ep reward: 200 seed: 847
# Test ep reward: 200 seed: 765
# Test ep reward: 200 seed: 868
# Test ep reward: 200 seed: 696
# Test ep reward: 200 seed: 404
# Test ep reward: 200 seed: 385
# Test ep reward: 200 seed: 171
# Test ep reward: 200 seed: 932
# Test ep reward: 200 seed: 407
# Average test reward: 200.0 episode length: 200.0

# %% [markdown]
# The agent acting in the environment can be seen using the following command. Change the ```path``` to pick the episode you want to visualize. Bear in mind by default video saving for training is taken every 50 episodes.

# %%
Video(work_dir/'video'/'SpinningReacher-v0'/'test'/f'ex1-episode-0.mp4',
      embed=True, html_attributes="loop autoplay") # Set html_attributes="controls" for video control
# Out:
# <video loop autoplay  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
t.train(cfg_path=Path().cwd()/'cfg'/'reacher_v1.yaml', 
      cfg_args=dict(env_name='TargetReacher-v0', train_episodes=500)) # < 5 mins
# Out:
# Numpy/Torch/Random Seed:  66
# Finishing last run (ID:jiwzvfkq) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>ep_reward</td><td>▂▁▃▃▃▂▂▅▃▁▄▄▃▃▅▆▄▆▄▆▇▅▇▄▆▇█▇██▇█████████</td></tr><tr><td>episodes</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>num_updates</td><td>▁▁▁▁█▁▁█▁▁▁▁▁▁▁▁▁█▁▁▁▁█▁▁▁█▁█▁█▁█▁█▁█▁█▁</td></tr><tr><td>timesteps</td><td>█▃███▂▅█▇▁██▄▄██▆█▄██▅█▃▇███████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>ep_reward</td><td>197</td></tr><tr><td>episodes</td><td>200</td></tr><tr><td>num_updates</td><td>0</td></tr><tr><td>timesteps</td><td>200</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ex1-SpinningReacher-v0-None-1694699727</strong> at: <a href='https://wandb.ai/springnuance/rl_aalto/runs/jiwzvfkq' target="_blank">https://wandb.ai/springnuance/rl_aalto/runs/jiwzvfkq</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230914_165527-jiwzvfkq/logs</code>
# Successfully finished last run (ID:jiwzvfkq). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666928653915723, max=1.0)…
# wandb version 0.15.10 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/notebooks/rl2023/ex1/wandb/run-20230914_165832-5c635s18</code>
# Syncing run <strong><a href='https://wandb.ai/springnuance/rl_aalto/runs/5c635s18' target="_blank">ex1-TargetReacher-v0-None-1694699912</a></strong> to <a href='https://wandb.ai/springnuance/rl_aalto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/springnuance/rl_aalto' target="_blank">https://wandb.ai/springnuance/rl_aalto</a>
#  View run at <a href='https://wandb.ai/springnuance/rl_aalto/runs/5c635s18' target="_blank">https://wandb.ai/springnuance/rl_aalto/runs/5c635s18</a>
# Configuration Settings: {'exp_name': 'ex1', 'seed': None, 'env_name': 'TargetReacher-v0', 'max_episode_steps': 200, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 2
# Action space dimensions: 5
#
# Episode 0 finished. Total reward: -640.1082541187618 (200 timesteps)
# Episode 1 finished. Total reward: -543.6358709640253 (200 timesteps)
# Episode 2 finished. Total reward: -551.7506997477625 (200 timesteps)
# Episode 3 finished. Total reward: -479.9402075384122 (200 timesteps)
# Episode 4 finished. Total reward: -395.2079500481197 (200 timesteps)
# Episode 5 finished. Total reward: -168.80526757164066 (113 timesteps)
# Episode 6 finished. Total reward: -500.8048382606324 (200 timesteps)
# Episode 7 finished. Total reward: -532.1601428772335 (200 timesteps)
# Episode 8 finished. Total reward: -363.3137189169592 (152 timesteps)
# Episode 9 finished. Total reward: -634.716534876936 (200 timesteps)
# Episode 10 finished. Total reward: -116.62192209466183 (51 timesteps)
# Updating the policy...
# Updating finished!
# Episode 11 finished. Total reward: -480.90813392508244 (200 timesteps)
# Episode 12 finished. Total reward: -216.06985277445906 (200 timesteps)
# Episode 13 finished. Total reward: -574.4837587720405 (200 timesteps)
# Episode 14 finished. Total reward: -439.42296942121465 (200 timesteps)
# Episode 15 finished. Total reward: -394.04413707114276 (200 timesteps)
# Episode 16 finished. Total reward: -315.7546348401568 (177 timesteps)
# Episode 17 finished. Total reward: -106.26922974986553 (59 timesteps)
# Episode 18 finished. Total reward: -498.73017554397757 (200 timesteps)
# Episode 19 finished. Total reward: -564.117677219023 (200 timesteps)
# Episode 20 finished. Total reward: -361.8975357636194 (200 timesteps)
# Episode 21 finished. Total reward: -422.76268727254984 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 22 finished. Total reward: -248.55857423592974 (117 timesteps)
# Episode 23 finished. Total reward: -510.0087641318793 (200 timesteps)
# Episode 24 finished. Total reward: -306.1558610786784 (146 timesteps)
# Episode 25 finished. Total reward: -426.5924486073535 (200 timesteps)
# Episode 26 finished. Total reward: -614.6877441620401 (200 timesteps)
# Episode 27 finished. Total reward: -186.72039664280072 (96 timesteps)
# Episode 28 finished. Total reward: -128.8059782081608 (54 timesteps)
# Episode 29 finished. Total reward: -292.3729001313713 (200 timesteps)
# Episode 30 finished. Total reward: -75.71734123023442 (52 timesteps)
# Episode 31 finished. Total reward: -434.3050906430099 (200 timesteps)
# Episode 32 finished. Total reward: -306.9361033297598 (200 timesteps)
# Episode 33 finished. Total reward: -177.20867982896218 (122 timesteps)
# Episode 34 finished. Total reward: -373.3464341760001 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 35 finished. Total reward: -467.7458445870194 (200 timesteps)
# Episode 36 finished. Total reward: -370.08712831727865 (200 timesteps)
# Episode 37 finished. Total reward: -72.93203066193803 (47 timesteps)
# Episode 38 finished. Total reward: -350.0224535963115 (200 timesteps)
# Episode 39 finished. Total reward: -107.79808694701335 (75 timesteps)
# Episode 40 finished. Total reward: -439.0071264646604 (200 timesteps)
# Episode 41 finished. Total reward: -109.95381567882627 (56 timesteps)
# Episode 42 finished. Total reward: -93.06249949422838 (63 timesteps)
# Episode 43 finished. Total reward: -144.19160231641558 (76 timesteps)
# Episode 44 finished. Total reward: -190.1689269166379 (79 timesteps)
# Episode 45 finished. Total reward: -201.2041869156946 (78 timesteps)
# Episode 46 finished. Total reward: -457.02343848797557 (200 timesteps)
# Episode 47 finished. Total reward: -316.35869751899395 (200 timesteps)
# Episode 48 finished. Total reward: -97.72381807410272 (48 timesteps)
# Episode 49 finished. Total reward: -323.20931054180335 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 50 finished. Total reward: -323.70941446690074 (193 timesteps)
# Episode 51 finished. Total reward: -58.654482315205136 (27 timesteps)
# Episode 52 finished. Total reward: -393.9126399278516 (200 timesteps)
# Episode 53 finished. Total reward: -131.05673468354652 (64 timesteps)
# Episode 54 finished. Total reward: -63.87199857814467 (47 timesteps)
# Episode 55 finished. Total reward: -38.95657639761451 (25 timesteps)
# Episode 56 finished. Total reward: -340.467988520974 (200 timesteps)
# Episode 57 finished. Total reward: -413.132226190235 (200 timesteps)
# Episode 58 finished. Total reward: -346.40006178369924 (200 timesteps)
# Episode 59 finished. Total reward: -334.78757033443543 (200 timesteps)
# Episode 60 finished. Total reward: -51.38382716142808 (39 timesteps)
# Episode 61 finished. Total reward: -77.60940971064973 (36 timesteps)
# Episode 62 finished. Total reward: -361.4596572797244 (200 timesteps)
# Episode 63 finished. Total reward: -428.56720273548876 (200 timesteps)
# Episode 64 finished. Total reward: -406.0625898981661 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 65 finished. Total reward: -364.32649476468464 (200 timesteps)
# Episode 66 finished. Total reward: -401.1741024797706 (200 timesteps)
# Episode 67 finished. Total reward: -381.16850854366794 (200 timesteps)
# Episode 68 finished. Total reward: -37.423510429858176 (21 timesteps)
# Episode 69 finished. Total reward: -45.680580702115776 (26 timesteps)
# Episode 70 finished. Total reward: -394.39485029578617 (200 timesteps)
# Episode 71 finished. Total reward: -42.783542006571615 (28 timesteps)
# Episode 72 finished. Total reward: -82.05782348982382 (45 timesteps)
# Episode 73 finished. Total reward: -372.70094619954375 (200 timesteps)
# Episode 74 finished. Total reward: -78.34895661263442 (45 timesteps)
# Episode 75 finished. Total reward: -59.19642700139984 (32 timesteps)
# Episode 76 finished. Total reward: -72.96469661516953 (36 timesteps)
# Episode 77 finished. Total reward: -375.612002720896 (200 timesteps)
# Episode 78 finished. Total reward: -74.11759107051807 (49 timesteps)
# Episode 79 finished. Total reward: -325.36767672809265 (200 timesteps)
# Episode 80 finished. Total reward: -63.55198325924937 (31 timesteps)
# Episode 81 finished. Total reward: -49.559030439895665 (34 timesteps)
# Episode 82 finished. Total reward: -37.80531911057454 (23 timesteps)
# Episode 83 finished. Total reward: -117.03811543754188 (77 timesteps)
# Episode 84 finished. Total reward: -275.93402280130346 (200 timesteps)
# Episode 85 finished. Total reward: -110.11508295357815 (64 timesteps)
# Updating the policy...
# Updating finished!
# Episode 86 finished. Total reward: -35.01030167088141 (28 timesteps)
# Episode 87 finished. Total reward: -164.7876071534597 (125 timesteps)
# Episode 88 finished. Total reward: -111.99630505365005 (88 timesteps)
# Episode 89 finished. Total reward: -42.80746713919387 (23 timesteps)
# Episode 90 finished. Total reward: -376.89148331194804 (200 timesteps)
# Episode 91 finished. Total reward: -44.48545484573824 (40 timesteps)
# Episode 92 finished. Total reward: -90.95010093921856 (65 timesteps)
# Episode 93 finished. Total reward: -313.76015549195364 (200 timesteps)
# Episode 94 finished. Total reward: -56.89154614043156 (32 timesteps)
# Episode 95 finished. Total reward: -109.1191142845253 (74 timesteps)
# Episode 96 finished. Total reward: -48.08654761957983 (29 timesteps)
# Episode 97 finished. Total reward: -39.68247057970048 (23 timesteps)
# Episode 98 finished. Total reward: -348.8721327844444 (200 timesteps)
# Episode 99 finished. Total reward: -85.42972489013286 (80 timesteps)
# Episode 100 finished. Total reward: -356.34787911863026 (200 timesteps)
# Episode 101 finished. Total reward: -152.6455041448695 (128 timesteps)
# Episode 102 finished. Total reward: -293.3953621916855 (200 timesteps)
# Episode 103 finished. Total reward: -51.98738676717712 (30 timesteps)
# Episode 104 finished. Total reward: -59.613272215129975 (32 timesteps)
# Episode 105 finished. Total reward: -53.70889475921722 (27 timesteps)
# Episode 106 finished. Total reward: -95.14616941613623 (53 timesteps)
# Episode 107 finished. Total reward: -42.39618422375323 (24 timesteps)
# Episode 108 finished. Total reward: -48.61799839354188 (26 timesteps)
# Episode 109 finished. Total reward: -47.80043159956162 (25 timesteps)
# Episode 110 finished. Total reward: -29.490064237471437 (19 timesteps)
# Updating the policy...
# Updating finished!
# Episode 111 finished. Total reward: -75.25698711490323 (41 timesteps)
# Episode 112 finished. Total reward: -26.488117614953637 (18 timesteps)
# Episode 113 finished. Total reward: -38.57657370359407 (22 timesteps)
# Episode 114 finished. Total reward: -43.84857324607274 (27 timesteps)
# Episode 115 finished. Total reward: -394.8717609238262 (200 timesteps)
# Episode 116 finished. Total reward: -43.12443374152172 (27 timesteps)
# Episode 117 finished. Total reward: -85.94823320069052 (59 timesteps)
# Episode 118 finished. Total reward: -388.95930925810114 (200 timesteps)
# Episode 119 finished. Total reward: -46.23873126704588 (25 timesteps)
# Episode 120 finished. Total reward: -33.3573979560112 (25 timesteps)
# Episode 121 finished. Total reward: -365.0723751035668 (200 timesteps)
# Episode 122 finished. Total reward: -64.42921896950577 (29 timesteps)
# Episode 123 finished. Total reward: -42.61369930635962 (26 timesteps)
# Episode 124 finished. Total reward: -35.7715384983545 (19 timesteps)
# Episode 125 finished. Total reward: -43.01366272099061 (22 timesteps)
# Episode 126 finished. Total reward: -366.8850549235345 (200 timesteps)
# Episode 127 finished. Total reward: -43.53454131428525 (22 timesteps)
# Episode 128 finished. Total reward: -53.37711640765234 (27 timesteps)
# Episode 129 finished. Total reward: -32.19838958928679 (17 timesteps)
# Episode 130 finished. Total reward: -48.93105797160405 (26 timesteps)
# Episode 131 finished. Total reward: -79.21757322963815 (72 timesteps)
# Episode 132 finished. Total reward: -100.51443307756615 (62 timesteps)
# Episode 133 finished. Total reward: -36.16691926549647 (23 timesteps)
# Episode 134 finished. Total reward: -32.85197063696553 (29 timesteps)
# Episode 135 finished. Total reward: -60.4346640086364 (53 timesteps)
# Episode 136 finished. Total reward: -353.7318830999045 (199 timesteps)
# Episode 137 finished. Total reward: -439.4553089293066 (200 timesteps)
# Episode 138 finished. Total reward: -29.485363057066188 (18 timesteps)
# Episode 139 finished. Total reward: -80.28419910306262 (66 timesteps)
# Episode 140 finished. Total reward: -70.32230852730224 (35 timesteps)
# Updating the policy...
# Updating finished!
# Episode 141 finished. Total reward: -85.88850775553999 (64 timesteps)
# Episode 142 finished. Total reward: -34.186907777437916 (21 timesteps)
# Episode 143 finished. Total reward: -109.84073694289432 (81 timesteps)
# Episode 144 finished. Total reward: -123.17009099311876 (104 timesteps)
# Episode 145 finished. Total reward: -41.77850122002556 (22 timesteps)
# Episode 146 finished. Total reward: -337.52478562817254 (200 timesteps)
# Episode 147 finished. Total reward: -98.07214112328981 (69 timesteps)
# Episode 148 finished. Total reward: -41.70001590551239 (28 timesteps)
# Episode 149 finished. Total reward: -44.485223399187305 (27 timesteps)
# Episode 150 finished. Total reward: -27.03270465603178 (19 timesteps)
# Episode 151 finished. Total reward: -29.854262558435607 (19 timesteps)
# Episode 152 finished. Total reward: -71.7906386390519 (56 timesteps)
# Episode 153 finished. Total reward: -42.946303825482715 (29 timesteps)
# Episode 154 finished. Total reward: -81.93927264242927 (44 timesteps)
# Episode 155 finished. Total reward: -68.05337646995845 (51 timesteps)
# Episode 156 finished. Total reward: -27.250801478053962 (16 timesteps)
# Episode 157 finished. Total reward: -30.5711132333542 (18 timesteps)
# Episode 158 finished. Total reward: -28.563083829050072 (18 timesteps)
# Episode 159 finished. Total reward: -138.8664693185737 (105 timesteps)
# Episode 160 finished. Total reward: -28.90033764004593 (17 timesteps)
# Episode 161 finished. Total reward: -46.10001468424224 (27 timesteps)
# Episode 162 finished. Total reward: -101.26104191223118 (82 timesteps)
# Episode 163 finished. Total reward: -49.04537561995982 (29 timesteps)
# Episode 164 finished. Total reward: -324.48900212537063 (200 timesteps)
# Episode 165 finished. Total reward: -113.72645409137057 (82 timesteps)
# Episode 166 finished. Total reward: -32.11653008259948 (21 timesteps)
# Episode 167 finished. Total reward: -46.67930382396915 (28 timesteps)
# Episode 168 finished. Total reward: -358.08345704925716 (200 timesteps)
# Episode 169 finished. Total reward: -54.97005274675372 (52 timesteps)
# Episode 170 finished. Total reward: -102.23301706470164 (73 timesteps)
# Episode 171 finished. Total reward: -38.255445344205086 (22 timesteps)
# Episode 172 finished. Total reward: -40.48825983561499 (24 timesteps)
# Episode 173 finished. Total reward: -61.689402227596226 (36 timesteps)
# Episode 174 finished. Total reward: -43.89985033648202 (32 timesteps)
# Episode 175 finished. Total reward: -34.199671282976325 (23 timesteps)
# Updating the policy...
# Updating finished!
# Episode 176 finished. Total reward: -324.7092016571887 (200 timesteps)
# Episode 177 finished. Total reward: -42.07661280905475 (33 timesteps)
# Episode 178 finished. Total reward: -29.742032499110373 (17 timesteps)
# Episode 179 finished. Total reward: -32.033531182417946 (19 timesteps)
# Episode 180 finished. Total reward: -34.08646374453711 (23 timesteps)
# Episode 181 finished. Total reward: -40.50939722564772 (22 timesteps)
# Episode 182 finished. Total reward: -44.52262389154985 (28 timesteps)
# Episode 183 finished. Total reward: -32.39928676668377 (17 timesteps)
# Episode 184 finished. Total reward: -340.58164093542945 (200 timesteps)
# Episode 185 finished. Total reward: -83.24678505533491 (78 timesteps)
# Episode 186 finished. Total reward: -30.512020520027445 (19 timesteps)
# Episode 187 finished. Total reward: -35.38332005149267 (22 timesteps)
# Episode 188 finished. Total reward: -45.84967025751179 (31 timesteps)
# Episode 189 finished. Total reward: -69.31677647714659 (58 timesteps)
# Episode 190 finished. Total reward: -346.18553064544136 (200 timesteps)
# Episode 191 finished. Total reward: -28.000559096506848 (17 timesteps)
# Episode 192 finished. Total reward: -39.70595899913433 (20 timesteps)
# Episode 193 finished. Total reward: -27.851140068695788 (20 timesteps)
# Episode 194 finished. Total reward: -49.177838119435826 (24 timesteps)
# Episode 195 finished. Total reward: -52.555016340120495 (30 timesteps)
# Episode 196 finished. Total reward: -78.90966610889922 (61 timesteps)
# Episode 197 finished. Total reward: -42.718532735525855 (26 timesteps)
# Episode 198 finished. Total reward: -29.741576929294993 (16 timesteps)
# Episode 199 finished. Total reward: -31.983567161160824 (17 timesteps)
# Episode 200 finished. Total reward: -36.28268184333299 (21 timesteps)
# Episode 201 finished. Total reward: -36.204646774834636 (21 timesteps)
# Episode 202 finished. Total reward: -86.44216701570873 (69 timesteps)
# Episode 203 finished. Total reward: -35.94698774725031 (22 timesteps)
# Episode 204 finished. Total reward: -43.931687332311746 (31 timesteps)
# Episode 205 finished. Total reward: -381.4835470666764 (200 timesteps)
# Episode 206 finished. Total reward: -32.56788925374875 (19 timesteps)
# Episode 207 finished. Total reward: -136.65859126969957 (107 timesteps)
# Episode 208 finished. Total reward: -123.22996497313409 (81 timesteps)
# Episode 209 finished. Total reward: -37.160637951419 (21 timesteps)
# Episode 210 finished. Total reward: -23.929186682775793 (14 timesteps)
# Episode 211 finished. Total reward: -29.52603526479861 (19 timesteps)
# Episode 212 finished. Total reward: -79.40670599636626 (66 timesteps)
# Episode 213 finished. Total reward: -42.21336601599938 (20 timesteps)
# Episode 214 finished. Total reward: -25.656739016334086 (18 timesteps)
# Episode 215 finished. Total reward: -48.15449835659716 (29 timesteps)
# Episode 216 finished. Total reward: -75.8411815625283 (60 timesteps)
# Episode 217 finished. Total reward: -53.73644006066531 (29 timesteps)
# Updating the policy...
# Updating finished!
# Episode 218 finished. Total reward: -359.00231379160687 (199 timesteps)
# Episode 219 finished. Total reward: -37.46150040384475 (25 timesteps)
# Episode 220 finished. Total reward: -68.89078287246126 (52 timesteps)
# Episode 221 finished. Total reward: -331.5508275702944 (182 timesteps)
# Episode 222 finished. Total reward: -25.57625710574863 (15 timesteps)
# Episode 223 finished. Total reward: -29.568677945428593 (17 timesteps)
# Episode 224 finished. Total reward: -354.4356179291744 (189 timesteps)
# Episode 225 finished. Total reward: -27.45025924021258 (18 timesteps)
# Episode 226 finished. Total reward: -34.081982772264304 (20 timesteps)
# Episode 227 finished. Total reward: -33.747579647388164 (20 timesteps)
# Episode 228 finished. Total reward: -82.22871805457544 (65 timesteps)
# Episode 229 finished. Total reward: -23.788468646125438 (14 timesteps)
# Episode 230 finished. Total reward: -27.56736472743903 (16 timesteps)
# Episode 231 finished. Total reward: -33.26409559649194 (23 timesteps)
# Episode 232 finished. Total reward: -80.2071679933992 (61 timesteps)
# Episode 233 finished. Total reward: -36.80890836031699 (30 timesteps)
# Episode 234 finished. Total reward: -31.714953048604354 (19 timesteps)
# Episode 235 finished. Total reward: -43.882660614391895 (27 timesteps)
# Episode 236 finished. Total reward: -49.12089257217573 (23 timesteps)
# Episode 237 finished. Total reward: -26.60331323796764 (16 timesteps)
# Episode 238 finished. Total reward: -379.90335620002617 (200 timesteps)
# Episode 239 finished. Total reward: -30.17527079750224 (19 timesteps)
# Episode 240 finished. Total reward: -50.67865750770103 (24 timesteps)
# Episode 241 finished. Total reward: -39.27288470464565 (22 timesteps)
# Episode 242 finished. Total reward: -28.290195687509108 (18 timesteps)
# Episode 243 finished. Total reward: -23.93262640111345 (15 timesteps)
# Episode 244 finished. Total reward: -92.42030456795558 (82 timesteps)
# Episode 245 finished. Total reward: -32.885455704519245 (26 timesteps)
# Episode 246 finished. Total reward: -27.109212344410103 (18 timesteps)
# Episode 247 finished. Total reward: -27.704941869019635 (16 timesteps)
# Episode 248 finished. Total reward: -73.07945389210455 (66 timesteps)
# Episode 249 finished. Total reward: -33.12667169230349 (20 timesteps)
# Episode 250 finished. Total reward: -24.988154395306285 (15 timesteps)
# Episode 251 finished. Total reward: -33.53359789508415 (20 timesteps)
# Episode 252 finished. Total reward: -23.97046690309896 (15 timesteps)
# Episode 253 finished. Total reward: -32.679042939260015 (19 timesteps)
# Episode 254 finished. Total reward: -27.484065100250177 (17 timesteps)
# Episode 255 finished. Total reward: -95.92926678082435 (72 timesteps)
# Episode 256 finished. Total reward: -28.59146490604286 (20 timesteps)
# Episode 257 finished. Total reward: -77.81511136988303 (62 timesteps)
# Episode 258 finished. Total reward: -26.5286675154726 (15 timesteps)
# Episode 259 finished. Total reward: -34.10349825369154 (20 timesteps)
# Episode 260 finished. Total reward: -353.9686022935228 (200 timesteps)
# Episode 261 finished. Total reward: -29.987572143569547 (21 timesteps)
# Updating the policy...
# Updating finished!
# Episode 262 finished. Total reward: -344.79954874355747 (200 timesteps)
# Episode 263 finished. Total reward: -335.57274471200276 (196 timesteps)
# Episode 264 finished. Total reward: -36.78610388650385 (21 timesteps)
# Episode 265 finished. Total reward: -309.0583461500259 (169 timesteps)
# Episode 266 finished. Total reward: -30.14143895674758 (20 timesteps)
# Episode 267 finished. Total reward: -30.026611525101476 (18 timesteps)
# Episode 268 finished. Total reward: -31.223268591302205 (19 timesteps)
# Episode 269 finished. Total reward: -71.71300054907039 (58 timesteps)
# Episode 270 finished. Total reward: -25.505294810766358 (16 timesteps)
# Episode 271 finished. Total reward: -27.30779816598103 (17 timesteps)
# Episode 272 finished. Total reward: -82.05543505737157 (66 timesteps)
# Episode 273 finished. Total reward: -63.39773145825519 (49 timesteps)
# Episode 274 finished. Total reward: -43.38983503783126 (25 timesteps)
# Episode 275 finished. Total reward: -81.51177965869854 (68 timesteps)
# Episode 276 finished. Total reward: -44.68007689639721 (25 timesteps)
# Episode 277 finished. Total reward: -77.5596053936676 (57 timesteps)
# Episode 278 finished. Total reward: -34.462980320450534 (22 timesteps)
# Episode 279 finished. Total reward: -29.697636996276604 (17 timesteps)
# Episode 280 finished. Total reward: -26.209261856231944 (17 timesteps)
# Episode 281 finished. Total reward: -64.11624464510587 (53 timesteps)
# Episode 282 finished. Total reward: -58.100591660933404 (49 timesteps)
# Episode 283 finished. Total reward: -299.8663537698836 (169 timesteps)
# Episode 284 finished. Total reward: -33.29973243632611 (21 timesteps)
# Episode 285 finished. Total reward: -78.12215699223684 (74 timesteps)
# Episode 286 finished. Total reward: -28.60184854695572 (20 timesteps)
# Episode 287 finished. Total reward: -52.05642871002183 (25 timesteps)
# Episode 288 finished. Total reward: -31.876301576566483 (19 timesteps)
# Episode 289 finished. Total reward: -28.151996587649773 (16 timesteps)
# Episode 290 finished. Total reward: -28.18067139512986 (16 timesteps)
# Episode 291 finished. Total reward: -45.11553571020121 (26 timesteps)
# Episode 292 finished. Total reward: -88.03870556870051 (66 timesteps)
# Episode 293 finished. Total reward: -359.43768248092294 (200 timesteps)
# Episode 294 finished. Total reward: -37.175639584466126 (21 timesteps)
# Episode 295 finished. Total reward: -29.76832158362449 (17 timesteps)
# Episode 296 finished. Total reward: -26.62290819183542 (16 timesteps)
# Episode 297 finished. Total reward: -53.10420163190795 (44 timesteps)
# Updating the policy...
# Updating finished!
# Episode 298 finished. Total reward: -307.49085723063774 (161 timesteps)
# Episode 299 finished. Total reward: -35.620236608098615 (19 timesteps)
# Episode 300 finished. Total reward: -28.426417489315686 (19 timesteps)
# Episode 301 finished. Total reward: -32.06048576390313 (18 timesteps)
# Episode 302 finished. Total reward: -326.8509965075771 (172 timesteps)
# Episode 303 finished. Total reward: -25.766506887227862 (17 timesteps)
# Episode 304 finished. Total reward: -27.526208249975475 (21 timesteps)
# Episode 305 finished. Total reward: -33.53185268428486 (21 timesteps)
# Episode 306 finished. Total reward: -80.50868982219612 (64 timesteps)
# Episode 307 finished. Total reward: -78.11091515021133 (69 timesteps)
# Episode 308 finished. Total reward: -27.714081758591604 (18 timesteps)
# Episode 309 finished. Total reward: -34.1184445253402 (18 timesteps)
# Episode 310 finished. Total reward: -29.33719339340454 (22 timesteps)
# Episode 311 finished. Total reward: -26.57557926791528 (15 timesteps)
# Episode 312 finished. Total reward: -36.14616976562383 (22 timesteps)
# Episode 313 finished. Total reward: -59.18519535852673 (56 timesteps)
# Episode 314 finished. Total reward: -35.56444599438644 (23 timesteps)
# Episode 315 finished. Total reward: -27.68294345443829 (17 timesteps)
# Episode 316 finished. Total reward: -23.69916211021478 (15 timesteps)
# Episode 317 finished. Total reward: -30.814944114349842 (20 timesteps)
# Episode 318 finished. Total reward: -26.019476108316834 (16 timesteps)
# Episode 319 finished. Total reward: -75.85972165204022 (60 timesteps)
# Episode 320 finished. Total reward: -26.418991047528934 (15 timesteps)
# Episode 321 finished. Total reward: -23.87898530509243 (14 timesteps)
# Episode 322 finished. Total reward: -28.88362830296146 (20 timesteps)
# Episode 323 finished. Total reward: -26.416550708639434 (17 timesteps)
# Episode 324 finished. Total reward: -24.355058852296832 (15 timesteps)
# Episode 325 finished. Total reward: -31.592975348923574 (17 timesteps)
# Episode 326 finished. Total reward: -26.662175562273635 (16 timesteps)
# Episode 327 finished. Total reward: -40.1082994498157 (27 timesteps)
# Episode 328 finished. Total reward: -26.436728200049647 (16 timesteps)
# Episode 329 finished. Total reward: -62.465632377395124 (57 timesteps)
# Episode 330 finished. Total reward: -63.19586625550749 (58 timesteps)
# Episode 331 finished. Total reward: -29.520626751799224 (17 timesteps)
# Episode 332 finished. Total reward: -73.96676082013713 (58 timesteps)
# Episode 333 finished. Total reward: -76.82949805877156 (66 timesteps)
# Episode 334 finished. Total reward: -26.243333191202417 (16 timesteps)
# Episode 335 finished. Total reward: -30.202788009513984 (17 timesteps)
# Episode 336 finished. Total reward: -30.12795985401405 (20 timesteps)
# Episode 337 finished. Total reward: -37.43799050417659 (23 timesteps)
# Episode 338 finished. Total reward: -40.304343019762456 (23 timesteps)
# Episode 339 finished. Total reward: -29.02614785129027 (17 timesteps)
# Episode 340 finished. Total reward: -29.40245668619488 (18 timesteps)
# Episode 341 finished. Total reward: -26.69253706438471 (16 timesteps)
# Episode 342 finished. Total reward: -35.42426251926238 (19 timesteps)
# Episode 343 finished. Total reward: -25.318621517501374 (15 timesteps)
# Episode 344 finished. Total reward: -28.205835916430487 (19 timesteps)
# Episode 345 finished. Total reward: -26.599130951536146 (17 timesteps)
# Episode 346 finished. Total reward: -37.00676864129691 (22 timesteps)
# Episode 347 finished. Total reward: -27.763596962219104 (20 timesteps)
# Episode 348 finished. Total reward: -25.45089105091547 (16 timesteps)
# Episode 349 finished. Total reward: -77.07853825953741 (65 timesteps)
# Episode 350 finished. Total reward: -30.770395333028933 (19 timesteps)
# Episode 351 finished. Total reward: -28.832616375434117 (16 timesteps)
# Episode 352 finished. Total reward: -28.189771624396883 (25 timesteps)
# Episode 353 finished. Total reward: -27.813047862363742 (18 timesteps)
# Episode 354 finished. Total reward: -34.487545430396125 (21 timesteps)
# Episode 355 finished. Total reward: -28.54029823314972 (25 timesteps)
# Episode 356 finished. Total reward: -27.09233216395732 (17 timesteps)
# Episode 357 finished. Total reward: -345.67466057358126 (200 timesteps)
# Episode 358 finished. Total reward: -27.429846460229218 (18 timesteps)
# Episode 359 finished. Total reward: -58.4948419701174 (60 timesteps)
# Episode 360 finished. Total reward: -28.96300754941073 (18 timesteps)
# Updating the policy...
# Updating finished!
# Episode 361 finished. Total reward: -27.426563800983764 (16 timesteps)
# Episode 362 finished. Total reward: -30.798886010556703 (19 timesteps)
# Episode 363 finished. Total reward: -36.06824639411758 (19 timesteps)
# Episode 364 finished. Total reward: -33.28186897325421 (19 timesteps)
# Episode 365 finished. Total reward: -30.117044013654855 (20 timesteps)
# Episode 366 finished. Total reward: -36.005798718318694 (20 timesteps)
# Episode 367 finished. Total reward: -30.129636189814963 (18 timesteps)
# Episode 368 finished. Total reward: -30.838897176799378 (19 timesteps)
# Episode 369 finished. Total reward: -26.139665331876113 (17 timesteps)
# Episode 370 finished. Total reward: -31.171169114295566 (17 timesteps)
# Episode 371 finished. Total reward: -24.181514126902734 (15 timesteps)
# Episode 372 finished. Total reward: -27.376173556992715 (17 timesteps)
# Episode 373 finished. Total reward: -33.366070200891905 (22 timesteps)
# Episode 374 finished. Total reward: -23.747354986372667 (15 timesteps)
# Episode 375 finished. Total reward: -37.56961401815423 (24 timesteps)
# Episode 376 finished. Total reward: -60.117108181331766 (53 timesteps)
# Episode 377 finished. Total reward: -34.228762683280394 (19 timesteps)
# Episode 378 finished. Total reward: -30.79880772273402 (21 timesteps)
# Episode 379 finished. Total reward: -23.79457642828325 (15 timesteps)
# Episode 380 finished. Total reward: -28.608430337410724 (18 timesteps)
# Episode 381 finished. Total reward: -28.97120054005289 (17 timesteps)
# Episode 382 finished. Total reward: -25.229575258046115 (18 timesteps)
# Episode 383 finished. Total reward: -26.82367610106887 (16 timesteps)
# Episode 384 finished. Total reward: -31.411066018182193 (18 timesteps)
# Episode 385 finished. Total reward: -24.634167225965935 (15 timesteps)
# Episode 386 finished. Total reward: -39.47624952017756 (21 timesteps)
# Episode 387 finished. Total reward: -25.808026772408603 (17 timesteps)
# Episode 388 finished. Total reward: -32.10175585314146 (19 timesteps)
# Episode 389 finished. Total reward: -77.13310646792198 (66 timesteps)
# Episode 390 finished. Total reward: -75.77753776058998 (68 timesteps)
# Episode 391 finished. Total reward: -31.821775304232098 (17 timesteps)
# Episode 392 finished. Total reward: -30.81957317870798 (17 timesteps)
# Episode 393 finished. Total reward: -26.42428573784644 (16 timesteps)
# Episode 394 finished. Total reward: -26.752772764522668 (15 timesteps)
# Episode 395 finished. Total reward: -29.742259290060748 (18 timesteps)
# Episode 396 finished. Total reward: -42.28909879433031 (29 timesteps)
# Episode 397 finished. Total reward: -43.46914811110611 (27 timesteps)
# Episode 398 finished. Total reward: -29.47811718156302 (18 timesteps)
# Episode 399 finished. Total reward: -30.074682210611 (17 timesteps)
# Episode 400 finished. Total reward: -30.76460429846554 (17 timesteps)
# Episode 401 finished. Total reward: -33.35293078419817 (19 timesteps)
# Episode 402 finished. Total reward: -30.071910618150334 (17 timesteps)
# Episode 403 finished. Total reward: -34.96839316018838 (19 timesteps)
# Episode 404 finished. Total reward: -24.99296449428809 (16 timesteps)
# Episode 405 finished. Total reward: -39.49801975029567 (29 timesteps)
# Episode 406 finished. Total reward: -30.89015037043742 (23 timesteps)
# Episode 407 finished. Total reward: -26.30141808244667 (15 timesteps)
# Episode 408 finished. Total reward: -25.038704480555772 (15 timesteps)
# Episode 409 finished. Total reward: -30.098524091724514 (17 timesteps)
# Episode 410 finished. Total reward: -26.69040930001867 (15 timesteps)
# Episode 411 finished. Total reward: -31.661665445874696 (17 timesteps)
# Episode 412 finished. Total reward: -23.19305873104351 (14 timesteps)
# Episode 413 finished. Total reward: -37.18145850138829 (21 timesteps)
# Episode 414 finished. Total reward: -29.93491924488223 (17 timesteps)
# Episode 415 finished. Total reward: -118.60938489157425 (95 timesteps)
# Episode 416 finished. Total reward: -34.050896826379116 (21 timesteps)
# Episode 417 finished. Total reward: -29.536777657073184 (18 timesteps)
# Episode 418 finished. Total reward: -26.897666416519094 (16 timesteps)
# Episode 419 finished. Total reward: -33.00113037075743 (20 timesteps)
# Episode 420 finished. Total reward: -28.664775186337117 (18 timesteps)
# Episode 421 finished. Total reward: -34.171699140923145 (23 timesteps)
# Episode 422 finished. Total reward: -31.80242482832923 (19 timesteps)
# Episode 423 finished. Total reward: -23.256160651896536 (14 timesteps)
# Episode 424 finished. Total reward: -36.439345210516265 (20 timesteps)
# Episode 425 finished. Total reward: -36.109859956081415 (23 timesteps)
# Episode 426 finished. Total reward: -32.90545369466666 (21 timesteps)
# Episode 427 finished. Total reward: -29.792283796562195 (19 timesteps)
# Episode 428 finished. Total reward: -29.405290693406183 (20 timesteps)
# Episode 429 finished. Total reward: -24.90033293748824 (16 timesteps)
# Episode 430 finished. Total reward: -26.425929574189297 (17 timesteps)
# Episode 431 finished. Total reward: -26.208739453378264 (16 timesteps)
# Episode 432 finished. Total reward: -32.309987985198816 (18 timesteps)
# Episode 433 finished. Total reward: -25.293182068706873 (15 timesteps)
# Episode 434 finished. Total reward: -25.66335765273412 (16 timesteps)
# Episode 435 finished. Total reward: -25.117656826986778 (15 timesteps)
# Episode 436 finished. Total reward: -30.087493658187764 (22 timesteps)
# Episode 437 finished. Total reward: -25.015197579878958 (15 timesteps)
# Episode 438 finished. Total reward: -106.46128983086459 (101 timesteps)
# Episode 439 finished. Total reward: -27.265217846068484 (16 timesteps)
# Episode 440 finished. Total reward: -27.672662586298962 (18 timesteps)
# Episode 441 finished. Total reward: -29.8293696610604 (16 timesteps)
# Episode 442 finished. Total reward: -75.79487341557281 (55 timesteps)
# Episode 443 finished. Total reward: -22.820860276039422 (14 timesteps)
# Episode 444 finished. Total reward: -31.564404660535164 (18 timesteps)
# Episode 445 finished. Total reward: -30.647996803586746 (19 timesteps)
# Episode 446 finished. Total reward: -24.00216853833868 (15 timesteps)
# Episode 447 finished. Total reward: -72.54079813746652 (58 timesteps)
# Episode 448 finished. Total reward: -28.547019912122252 (18 timesteps)
# Episode 449 finished. Total reward: -33.07539125700202 (19 timesteps)
# Episode 450 finished. Total reward: -29.787668745187876 (18 timesteps)
# Updating the policy...
# Updating finished!
# Episode 451 finished. Total reward: -54.68369399981989 (44 timesteps)
# Episode 452 finished. Total reward: -28.35954316536803 (17 timesteps)
# Episode 453 finished. Total reward: -27.315732431128087 (17 timesteps)
# Episode 454 finished. Total reward: -27.845841130331323 (18 timesteps)
# Episode 455 finished. Total reward: -27.94411085886444 (16 timesteps)
# Episode 456 finished. Total reward: -26.109409862109473 (16 timesteps)
# Episode 457 finished. Total reward: -28.3609084517763 (16 timesteps)
# Episode 458 finished. Total reward: -81.55656654889302 (65 timesteps)
# Episode 459 finished. Total reward: -26.40950690088051 (16 timesteps)
# Episode 460 finished. Total reward: -26.888309472698637 (15 timesteps)
# Episode 461 finished. Total reward: -26.35734510178008 (15 timesteps)
# Episode 462 finished. Total reward: -54.462619586393444 (46 timesteps)
# Episode 463 finished. Total reward: -31.580078361440037 (19 timesteps)
# Episode 464 finished. Total reward: -29.068823162435727 (17 timesteps)
# Episode 465 finished. Total reward: -25.77314297362126 (15 timesteps)
# Episode 466 finished. Total reward: -25.68541629594673 (15 timesteps)
# Episode 467 finished. Total reward: -348.6517406374762 (200 timesteps)
# Episode 468 finished. Total reward: -31.89600890791584 (17 timesteps)
# Episode 469 finished. Total reward: -61.781616631749 (49 timesteps)
# Episode 470 finished. Total reward: -324.12238171702944 (200 timesteps)
# Episode 471 finished. Total reward: -28.84079809662177 (18 timesteps)
# Episode 472 finished. Total reward: -31.51000474811347 (19 timesteps)
# Episode 473 finished. Total reward: -29.44747522129785 (18 timesteps)
# Episode 474 finished. Total reward: -27.62600936256048 (18 timesteps)
# Episode 475 finished. Total reward: -57.302690994158105 (49 timesteps)
# Episode 476 finished. Total reward: -38.93655985925229 (22 timesteps)
# Episode 477 finished. Total reward: -27.978680648428323 (16 timesteps)
# Episode 478 finished. Total reward: -29.723561007526772 (18 timesteps)
# Episode 479 finished. Total reward: -28.42526585108064 (16 timesteps)
# Episode 480 finished. Total reward: -26.314097968345727 (15 timesteps)
# Episode 481 finished. Total reward: -40.39112930374107 (24 timesteps)
# Episode 482 finished. Total reward: -24.973070977681726 (15 timesteps)
# Episode 483 finished. Total reward: -30.105201687969867 (17 timesteps)
# Episode 484 finished. Total reward: -27.3879765549021 (16 timesteps)
# Episode 485 finished. Total reward: -32.43999386665249 (18 timesteps)
# Episode 486 finished. Total reward: -29.808569810960186 (17 timesteps)
# Episode 487 finished. Total reward: -25.071280649939613 (15 timesteps)
# Episode 488 finished. Total reward: -26.290970828199846 (16 timesteps)
# Episode 489 finished. Total reward: -30.91757013626516 (17 timesteps)
# Episode 490 finished. Total reward: -24.113689228778895 (14 timesteps)
# Episode 491 finished. Total reward: -25.037034082434637 (15 timesteps)
# Episode 492 finished. Total reward: -30.41768812757672 (17 timesteps)
# Episode 493 finished. Total reward: -37.33881653641686 (20 timesteps)
# Episode 494 finished. Total reward: -40.648565911207605 (22 timesteps)
# Episode 495 finished. Total reward: -29.09345966442019 (17 timesteps)
# Episode 496 finished. Total reward: -28.59863741918726 (17 timesteps)
# Episode 497 finished. Total reward: -259.0768979200604 (150 timesteps)
# Episode 498 finished. Total reward: -25.74249799714972 (15 timesteps)
# Episode 499 finished. Total reward: -29.312660946081515 (18 timesteps)
# Episode 500 finished. Total reward: -37.31962212958005 (20 timesteps)
# Model saved to /notebooks/rl2023/ex1/results/model/TargetReacher-v0_params.pt
# ------Training finished.------

# %%
t.test(episodes=10, cfg_path=Path().cwd()/'cfg'/'reacher_v1.yaml', 
       cfg_args=dict(env_name='TargetReacher-v0', seed=None, testing=True, use_wandb=False))
# Out:
# Numpy/Torch/Random Seed:  881
# Loading model from /notebooks/rl2023/ex1/results/model/TargetReacher-v0_params.pt ...
# Testing...
# Test ep reward: -27.083437040442625 seed: 65
# Test ep reward: -24.367628632048486 seed: 664
# Test ep reward: -25.516414709071878 seed: 165
# Test ep reward: -24.832561125298216 seed: 336
# Test ep reward: -25.64620203865098 seed: 122
# Test ep reward: -24.463946515659828 seed: 599
# Test ep reward: -25.87917390384767 seed: 771
# Test ep reward: -23.98458372769076 seed: 5
# Test ep reward: -26.09661902217892 seed: 126
# Test ep reward: -25.07130898555894 seed: 557
# Average test reward: -25.29418757004483 episode length: 15.2

# %%
Video(work_dir/'video'/'TargetReacher-v0'/'test'/f'ex1-episode-0.mp4',
      embed=True, html_attributes="loop autoplay") # Set html_attributes="controls" for video control
# Out:
# <video loop autoplay  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# <a id='T4'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 4.</b> Visualizing Behavior (10 points) </h3>
#
# Now, let us visualize the reward function for the second behavior (reaching the goal [1,1]). Plot the values of the second reward function from Task 3 and the learned best action as a function of the state (the joint positions). Use the code below as a starting point. After plotting, answer the questions below.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import gymnasium as gym
from agent import Agent, Policy

# %%
env_name = "TargetReacher-v0" 
resolution = 101  # Resolution of the policy/reward image

# Load policy from default path to plot
policy_dir = Path().cwd()/'results'/'model'/f'{env_name}_params.pt'

sns.set()

# Create a gym environment
env = gym.make(env_name)

action_space_dim = u.get_space_dim(env.action_space)
observation_space_dim = u.get_space_dim(env.observation_space)
policy = Policy(observation_space_dim, action_space_dim)

if policy_dir:
    policy.load_state_dict(torch.load(policy_dir))
    print("Loading policy from", policy_dir)
else:
    print("Plotting a random policy")
# Out:
# Loading policy from /notebooks/rl2023/ex1/results/model/TargetReacher-v0_params.pt

# %%
# Create a grid and initialize arrays to store rewards and actions
npoints = resolution
state_range = np.linspace(-np.pi, np.pi, npoints)
rewards = np.zeros((npoints, npoints))
actions = np.zeros((npoints, npoints), dtype=np.int32)

# Loop through state[0] and state[1]
for i,th1 in enumerate(state_range):
    for j,th2 in enumerate(state_range):
        # Create the state vector from th1, th2
        state = np.array([th1, th2])

        # Query the policy and find the most probable action
        with torch.no_grad():
            action_dist, _ = policy(torch.from_numpy(state).float().unsqueeze(0))
        action_probs = action_dist.probs.numpy()

        # TODO: Task 4: 1. What's the best action, according to the policy?
        # .             2. Compute the reward given state
        ########## Your code starts here ##########
        # Use the action probabilities in the action_probs vector
        # (it's a numpy array)
        # actions[i, j] = 0
        # rewards[i,j] = 0 
        actions[i,j] = action_probs.argmax()
        rewards[i,j] = env.get_reward(None, None, state)
        ########## Your code ends here ##########
# Out:
# /opt/software/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.get_reward to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_reward` for environment variables or `env.get_wrapper_attr('get_reward')` that will search the reminding wrappers.
#   logger.warn(

# %%
# Create the reward plot
num_ticks = 10
tick_skip = max(1, npoints // num_ticks)
tick_shift = 2*np.pi/npoints/2
tick_points = np.arange(npoints)[::tick_skip] + tick_shift
tick_labels = state_range.round(2)[::tick_skip]

sns.heatmap(rewards)
plt.xticks(tick_points, tick_labels, rotation=45)
plt.yticks(tick_points, tick_labels, rotation=45)
plt.xlabel("J2")
plt.ylabel("J1")
plt.title("Reward")
plt.suptitle("Rewards in %s" % env_name)
plt.show()

# %%
# # Create the policy plot
cmap = sns.color_palette("deep", action_space_dim)
sns.heatmap(actions, cmap=cmap, vmin=0, vmax=action_space_dim-1)
plt.xticks(tick_points, tick_labels, rotation=45)
plt.yticks(tick_points, tick_labels, rotation=45)
colorbar = plt.gca().collections[0].colorbar
ticks = np.array(range(action_space_dim))*((action_space_dim-1)/action_space_dim)+0.5
colorbar.set_ticks(ticks)
if env.spec.id == "Reacher-v1":
    # In Reacher, we can replace 0..4 with more readable labels
    labels = ["J1+", "J1-", "J2+", "J2-", "Stop"]
else:
    labels = list(map(str, range(action_space_dim)))
colorbar.set_ticklabels(labels)
plt.xlabel("J2")
plt.ylabel("J1")
plt.title("Best action")
plt.suptitle("Best action in %s" % env_name)
plt.show()

# %% [markdown]
# <a id='3.2.1'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 4.1</b> Achieved Performance (5 points) </h3>
#
# Where are the highest and lowest reward achieved?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
# Find highest and lowest reward state
# min and max are reversed because the reward is negative
max_idx = np.unravel_index(np.argmin(rewards), rewards.shape)
min_idx = np.unravel_index(np.argmax(rewards), rewards.shape)

max_state = np.array([state_range[max_idx[0]], state_range[max_idx[1]]])
min_state = np.array([state_range[min_idx[0]], state_range[min_idx[1]]])

print("Maximum value state:", max_state)
print("Minimum value state:", min_state)
# Out:
# Maximum value state: [-8.1681409e-01  4.4408921e-16]
# Minimum value state: [-3.14159265 -1.57079633]

# %% [markdown]
# The highest reward is achieved at the region with darkest color and the lowest reward is achieved at the region with lightest color in the rewards in Reacher-v1 graph. By some python code, I can determine that the state with highest reward is [-8.1681409e-01  4.4408921e-16] and the state with lowest reward is [-3.14159265 -1.57079633]

# %% [markdown]
# <a id='Q5'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 4.2</b> Analysis of Behaviour (10 points) </h3>
#
# Did the policy learn to reach the goal from every possible state (manipulator configuration) in an optimal way (i.e. with lowest possible number of steps)? Why/why not?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# In the best action in TargetReacher-v1 plot, we can see that the model only recognizes two actions, 0 and 2, which correspond to increasing values of two rotating joint angular parameters $\theta_0$ and $\theta_1$. This means that the model is always rotating anticlockwise. This behavior is optimal when the initial state is close to the goal in anticlockwise direction. However, this policy will not reach the goal in an optimal way if the initial state has the goal in the clockwise direction from the reacher. This is because the reacher will instead rotate anticlockwise in the long way to reach the goal instead of choosing the shorter way by rotating clockwise. This is because the actions 1 and 3 are never recognized in this policy.

# %% [markdown]
# # 4. Submitting <a id='4.'></a>
# Ensure all tasks and questions (in ```ex1.ipynb```) are answered and the relevant plots are recorded in the relevant places. Details about attaching images and figures can be found below. The relevant graphs to be included for this assignment are:
# - Task 1, WandB CartPole ```episodesep_reward``` plot
# - x2 Task 4 reward plots
#
# Ensure the correct model files are saved:
# - results/model/CartPole-v1_params.pt
# - results/model/SpinningReacher-v0_params.pt
# - results/model/TargetReacher-v0_params.pt

# %% [markdown]
# ## 4.1 Feedback <a id='4.1'></a>
# In order to help the staff of the course as well as the forthcoming students, it would be great if you could
# answer feedback questionnaire in ```feedback.ipynb```

# %% [markdown]
# The assignment is not very difficult but the super frustrating thing is that the wandb server is constantly showing errors and I had to spend idle time waiting for the training to finish. Overall, Exercise 1 gives a gentle introduction plus the tools in RL. I rate it 8/10.

# %% [markdown]
# Please use the following section to record references.
# # References <a id='5.'></a>

# %% [markdown]
# I have no references in this exercise.
